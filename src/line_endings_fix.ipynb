# %%
from pathlib import Path
files = [
    Path('src/ai.functions.server.ts'),
    Path('src/router.tsx'),
    Path('src/components/DefaultErrorComponent.tsx'),
]
for p in files:
    text = p.read_text(encoding='utf-8')
    p.write_text(text.replace('\r\n', '\n'), encoding='utf-8')
print('done')
